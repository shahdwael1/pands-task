# %% [markdown]
# # <center><font color='RED'>**CAT Reloaded Data Science**</center></font>
# <center>```Beginner's task 4 (Pandas Continued)```</center>

# %% [markdown]
# # <font color='darkgreen'> **Download Dataset**
# ### [**survey_results_public_Dataset**](https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2019.zip)

# %% [markdown]
# ### 1. Show your data after sorting it (descendingly by `Country`) & (ascendingly by `SocialMedia`) :

# %%
import pandas as pd
df=pd.read_csv('/content/survey_results_public.csv')
df.sort_values(by=['Country','SocialMedia'],ascending=[False,True])
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 13329       13392  I am a student who is learning to code      Yes
# 15220       15299          I am a developer by profession      Yes
# 6460         6486  I am a student who is learning to code      Yes
# 30560       30743          I am a developer by profession      Yes
# 2521         2530          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 719           722          I am a developer by profession       No
# 28470       28638          I am a developer by profession      Yes
# 29560       29736          I am a developer by profession      Yes
# 42832       43106          I am a developer by profession      Yes
# 49377       49702          I am a developer by profession       No
#
#                                              OpenSourcer  \
# 13329                                              Never
# 15220                                              Never
# 6460                                               Never
# 30560  Less than once a month but more than once per ...
# 2521   Less than once a month but more than once per ...
# ...                                                  ...
# 719    Less than once a month but more than once per ...
# 28470  Less than once a month but more than once per ...
# 29560  Less than once a month but more than once per ...
# 42832                                              Never
# 49377                                              Never
#
#                                               OpenSource  \
# 13329  OSS is, on average, of HIGHER quality than pro...
# 15220  The quality of OSS and closed source software ...
# 6460   OSS is, on average, of HIGHER quality than pro...
# 30560  The quality of OSS and closed source software ...
# 2521   OSS is, on average, of LOWER quality than prop...
# ...                                                  ...
# 719    The quality of OSS and closed source software ...
# 28470  OSS is, on average, of HIGHER quality than pro...
# 29560  OSS is, on average, of HIGHER quality than pro...
# 42832  OSS is, on average, of LOWER quality than prop...
# 49377  The quality of OSS and closed source software ...
#
#                                               Employment      Country  \
# 13329                 Not employed, but looking for work     Zimbabwe
# 15220  Independent contractor, freelancer, or self-em...     Zimbabwe
# 6460                                  Employed part-time     Zimbabwe
# 30560                                 Employed full-time     Zimbabwe
# 2521                                  Employed full-time     Zimbabwe
# ...                                                  ...          ...
# 719                                                  NaN  Afghanistan
# 28470  Independent contractor, freelancer, or self-em...  Afghanistan
# 29560                                 Employed full-time  Afghanistan
# 42832                                 Employed part-time  Afghanistan
# 49377                                 Employed full-time  Afghanistan
#
#               Student                                            EdLevel  \
# 13329  Yes, full-time  Secondary school (e.g. American high school, G...
# 15220              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6460   Yes, full-time  Secondary school (e.g. American high school, G...
# 30560              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2521   Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...                                                ...
# 719               NaN                                                NaN
# 28470             NaN          Other doctoral degree (Ph.D, Ed.D., etc.)
# 29560  Yes, part-time                          Primary/elementary school
# 42832  Yes, part-time                          Primary/elementary school
# 49377             NaN                                                NaN
#
#                                           UndergradMajor  ...  \
# 13329                                                NaN  ...
# 15220                          Mathematics or statistics  ...
# 6460                                                 NaN  ...
# 30560  Computer science, computer engineering, or sof...  ...
# 2521   Information systems, information technology, o...  ...
# ...                                                  ...  ...
# 719                                                  NaN  ...
# 28470                           I never declared a major  ...
# 29560                                                NaN  ...
# 42832                                                NaN  ...
# 49377                                                NaN  ...
#
#                                            WelcomeChange  \
# 13329            Just as welcome now as I felt last year
# 15220            Just as welcome now as I felt last year
# 6460               A lot more welcome now than last year
# 30560           Somewhat more welcome now than last year
# 2521             Just as welcome now as I felt last year
# ...                                                  ...
# 719    Not applicable - I did not use Stack Overflow ...
# 28470              A lot less welcome now than last year
# 29560            Just as welcome now as I felt last year
# 42832              A lot more welcome now than last year
# 49377                                                NaN
#
#                                             SONewContent   Age Gender Trans  \
# 13329  Tech articles written by other developers;Indu...  25.0    Man    No
# 15220  Tech articles written by other developers;Indu...  35.0    Man    No
# 6460   Tech articles written by other developers;Indu...  21.0  Woman    No
# 30560                Tech meetups or events in your area  24.0    Man    No
# 2521   Tech articles written by other developers;Indu...   NaN    Man    No
# ...                                                  ...   ...    ...   ...
# 719                                                  NaN   1.0    NaN   NaN
# 28470                                                NaN   NaN    NaN   NaN
# 29560       Courses on technologies you're interested in  26.0    Man    No
# 42832       Courses on technologies you're interested in   NaN    NaN   NaN
# 49377                                                NaN   NaN    NaN   NaN
#
#                      Sexuality                    Ethnicity Dependents  \
# 13329  Straight / Heterosexual  Black or of African descent         No
# 15220  Straight / Heterosexual  Black or of African descent        Yes
# 6460   Straight / Heterosexual  Black or of African descent         No
# 30560  Straight / Heterosexual  Black or of African descent         No
# 2521   Straight / Heterosexual  Black or of African descent        Yes
# ...                        ...                          ...        ...
# 719                        NaN                          NaN        NaN
# 28470                      NaN                          NaN        NaN
# 29560                      NaN                          NaN        Yes
# 42832                      NaN                          NaN        NaN
# 49377                      NaN                          NaN        NaN
#
#                 SurveyLength                  SurveyEase
# 13329               Too long  Neither easy nor difficult
# 15220               Too long                        Easy
# 6460   Appropriate in length                        Easy
# 30560  Appropriate in length                        Easy
# 2521                Too long                        Easy
# ...                      ...                         ...
# 719                 Too long                   Difficult
# 28470               Too long                         NaN
# 29560               Too long                        Easy
# 42832                    NaN                         NaN
# 49377               Too long                   Difficult
#
# [50118 rows x 85 columns]

# %%
# sort data here:

# %% [markdown]
# ___________________________________________________________________________________________

# %% [markdown]
# ### Group the dateframe by `Country` for the following questions:

# %%
data_group = df.groupby(['Country'])

# %% [markdown]
# ### 1. Show value counts for `Student` in the `United Kingdom`

# %% [markdown]
# #### a. How many are full-time students ?
# #### b. How many are not students ?

# %%
data_group['Student'].value_counts().loc['United Kingdom']
# Out:
# Student
# No                2777
# Yes, full-time     316
# Yes, part-time      97
# Name: Student, dtype: int64

# %% [markdown]
# ### 2. What's the median sallary `ConvertedComp` for developers in `Germany`,  `Italy`, `Finland`

# %%
data_group['ConvertedComp'].median().loc['Germany']
# Out:
# 61872.0

# %%
data_group['ConvertedComp'].median().loc['Italy']
# Out:
# 34372.0

# %%
data_group['ConvertedComp'].median().loc['Finland']
# Out:
# 56142.0

# %% [markdown]
# ### 3. Show the number of respondents from each country

# %%
country_re=data_group['Respondent'].value_counts()

# %% [markdown]
# ### 4. Show the number of respondents that worked with `Android` from each country mentioned in column `PlatformWorkedWith`

# %%
 android_data =data_group['PlatformWorkedWith'].apply(lambda x: x.str.contains('Android').sum())

# %% [markdown]
# ### 5. the function **`pandas.concat()`** to add these two series together in a new DataFrame

# %%
concat_df=pd.concat([country_re,android_data],axis='columns')
concat_df
# Out:
#                   Respondent  PlatformWorkedWith
# Country
# Afghanistan 722          1.0                 NaN
#             6417         1.0                 NaN
#             7085         1.0                 NaN
#             7353         1.0                 NaN
#             8149         1.0                 NaN
# ...                      ...                 ...
# V           e            NaN                 NaN
#             i            NaN                 NaN
# Y           e            NaN                 NaN
# Z           a            NaN                 NaN
#             i            NaN                 NaN
#
# [50293 rows x 2 columns]

# %% [markdown]
# ### 6. Add a new column contains the percentage of people that worked with `Android` from each country

# %%
concat_df['pctdata']=(concat_df['Respondent']/concat_df['PlatformWorkedWith']) *100
concat_df
# Out:
#                   Respondent  PlatformWorkedWith  pctdata
# Country
# Afghanistan 722          1.0                 NaN      NaN
#             6417         1.0                 NaN      NaN
#             7085         1.0                 NaN      NaN
#             7353         1.0                 NaN      NaN
#             8149         1.0                 NaN      NaN
# ...                      ...                 ...      ...
# V           e            NaN                 NaN      NaN
#             i            NaN                 NaN      NaN
# Y           e            NaN                 NaN      NaN
# Z           a            NaN                 NaN      NaN
#             i            NaN                 NaN      NaN
#
# [50293 rows x 3 columns]

# %% [markdown]
# ### 7. Tell the difference between the following two cells:
# > **`hint`**: what does each cell do

# %%
sorted_data = df[["Country" , "ConvertedComp"]].sort_values(by=["Country" , "ConvertedComp"], ascending = [True,False])
sorted_data.head(50)
# Out:
#            Country  ConvertedComp
# 39018  Afghanistan        19152.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 719    Afghanistan            0.0
# 28470  Afghanistan            0.0
# 6391   Afghanistan            NaN
# 7323   Afghanistan            NaN
# 12253  Afghanistan            NaN
# 26189  Afghanistan            NaN
# 28877  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 37571  Afghanistan            NaN
# 39754  Afghanistan            NaN
# 42832  Afghanistan            NaN
# 44123  Afghanistan            NaN
# 45562  Afghanistan            NaN
# 46807  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 38075      Albania       187668.0
# 3771       Albania       114550.0
# 9230       Albania        74474.0
# 6688       Albania        60000.0
# 10257      Albania        57300.0
# 28705      Albania        34368.0
# 38693      Albania        24729.0
# 36348      Albania        23952.0
# 50000      Albania        23376.0
# 2324       Albania        22080.0
# 43601      Albania        20628.0
# 12208      Albania        18768.0
# 18193      Albania        13800.0
# 28995      Albania        13752.0
# 1946       Albania        11040.0
# 21584      Albania        11040.0
# 13322      Albania        10596.0
# 24955      Albania         9936.0
# 27476      Albania         9624.0
# 15910      Albania         8832.0
# 35805      Albania         8832.0
# 15295      Albania         7728.0
# 18766      Albania         7728.0
# 40574      Albania         7728.0
# 11496      Albania         6624.0
# 33385      Albania         5520.0
# 33999      Albania         5496.0
# 25440      Albania         4416.0

# %%
grouped_data = df[["Country" , "ConvertedComp"]].groupby('Country').agg({"ConvertedComp":"median"})
grouped_data.head(50)
# Out:
#                                        ConvertedComp
# Country
# Afghanistan                                   3996.0
# Albania                                      12396.0
# Algeria                                       6096.0
# Andorra                                          NaN
# Angola                                        7764.0
# Antigua and Barbuda                              NaN
# Argentina                                    17760.0
# Armenia                                      18456.0
# Australia                                    79783.0
# Austria                                      52110.0
# Azerbaijan                                   14100.0
# Bahamas                                          NaN
# Bahrain                                      15912.0
# Bangladesh                                    8604.0
# Barbados                                     21000.0
# Belarus                                      25200.0
# Belgium                                      48120.0
# Belize                                           NaN
# Benin                                            NaN
# Bhutan                                           NaN
# Bolivia                                      17364.0
# Bosnia and Herzegovina                       18288.0
# Botswana                                     50000.0
# Brazil                                       18036.0
# Brunei Darussalam                             6096.0
# Bulgaria                                     28080.0
# Burkina Faso                                  8388.0
# Burundi                                       3606.0
# Cambodia                                     10300.0
# Cameroon                                      5664.0
# Canada                                       68705.0
# Cape Verde                                       NaN
# Chile                                        27528.0
# China                                        29652.0
# Colombia                                     15528.0
# Congo, Republic of the...                    12600.0
# Costa Rica                                   34772.0
# Croatia                                      25968.0
# Cuba                                          3600.0
# Cyprus                                       38496.0
# Czech Republic                               34752.0
# Côte d'Ivoire                                13626.0
# Democratic People's Republic of Korea            NaN
# Democratic Republic of the Congo                 NaN
# Denmark                                      82860.0
# Djibouti                                     18876.0
# Dominica                                         NaN
# Dominican Republic                           19909.5
# Ecuador                                      21600.0
# Egypt                                         8844.0

# %%
# Tell the difference here:
#we sort the just two colums
#we will qroup the country and give the median of ConvertedComp for each country

# %% [markdown]
# ### 1. remove nan values

# %%
#write code
df.dropna()
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 50113       50440  I am not primarily a developer, but I write co...       No
# 50114       50441  I am not primarily a developer, but I write co...       No
# 50115       50442                     I am a developer by profession       No
# 50116       50443                     I am a developer by profession      Yes
# 50117       50444                     I am a developer by profession      Yes
#
#                       OpenSourcer  \
# 0                           Never
# 1         Less than once per year
# 2                           Never
# 3                           Never
# 4      Once a month or more often
# ...                           ...
# 50113                       Never
# 50114     Less than once per year
# 50115  Once a month or more often
# 50116                       Never
# 50117     Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 50113  OSS is, on average, of LOWER quality than prop...
# 50114  The quality of OSS and closed source software ...
# 50115  The quality of OSS and closed source software ...
# 50116  The quality of OSS and closed source software ...
# 50117  The quality of OSS and closed source software ...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 50113  Independent contractor, freelancer, or self-em...
# 50114                                 Employed full-time
# 50115                                 Employed full-time
# 50116                                 Employed full-time
# 50117                                 Employed full-time
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 50113                 Germany  Yes, full-time
# 50114                 Germany              No
# 50115                 Romania              No
# 50116                  Mexico              No
# 50117           United States              No
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 50113        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 50114        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 50115        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 50116           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 50117           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           UndergradMajor  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                          Web development or web design  ...
# 3      Computer science, computer engineering, or sof...  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 50113  Computer science, computer engineering, or sof...  ...
# 50114  Another engineering discipline (ex. civil, ele...  ...
# 50115  Computer science, computer engineering, or sof...  ...
# 50116  Computer science, computer engineering, or sof...  ...
# 50117  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 50113   Just as welcome now as I felt last year
# 50114   Just as welcome now as I felt last year
# 50115   Just as welcome now as I felt last year
# 50116  Somewhat less welcome now than last year
# 50117                                       NaN
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 50113                                                NaN  56.0    Man    No
# 50114                                                NaN  25.0    Man    No
# 50115                                                NaN  27.0  Woman    No
# 50116       Courses on technologies you're interested in  28.0    Man    No
# 50117                                                NaN   NaN    NaN   NaN
#
#                      Sexuality                                 Ethnicity  \
# 0      Straight / Heterosexual                                       NaN
# 1      Straight / Heterosexual                                       NaN
# 2      Straight / Heterosexual                                       NaN
# 3      Straight / Heterosexual              White or of European descent
# 4      Straight / Heterosexual  White or of European descent;Multiracial
# ...                        ...                                       ...
# 50113  Straight / Heterosexual              White or of European descent
# 50114  Straight / Heterosexual              White or of European descent
# 50115                 Bisexual              White or of European descent
# 50116  Straight / Heterosexual                 Hispanic or Latino/Latina
# 50117                      NaN                                       NaN
#
#       Dependents           SurveyLength                  SurveyEase
# 0             No  Appropriate in length  Neither easy nor difficult
# 1             No  Appropriate in length  Neither easy nor difficult
# 2            Yes  Appropriate in length  Neither easy nor difficult
# 3             No  Appropriate in length                        Easy
# 4             No  Appropriate in length                        Easy
# ...          ...                    ...                         ...
# 50113        Yes               Too long  Neither easy nor difficult
# 50114         No               Too long                        Easy
# 50115         No  Appropriate in length                        Easy
# 50116         No  Appropriate in length                        Easy
# 50117        NaN                    NaN                         NaN
#
# [50118 rows x 85 columns]

# %% [markdown]
# ### 2. make sure there is not nan values

# %%
#write code
df.isna()
# Out:
#        Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# 0           False       False     False        False       False       False
# 1           False       False     False        False       False       False
# 2           False       False     False        False       False       False
# 3           False       False     False        False       False       False
# 4           False       False     False        False       False       False
# ...           ...         ...       ...          ...         ...         ...
# 50113       False       False     False        False       False       False
# 50114       False       False     False        False       False       False
# 50115       False       False     False        False       False       False
# 50116       False       False     False        False       False       False
# 50117       False       False     False        False       False       False
#
#        Country  Student  EdLevel  UndergradMajor  ...  WelcomeChange  \
# 0        False    False    False            True  ...          False
# 1        False    False    False            True  ...          False
# 2        False    False    False           False  ...          False
# 3        False    False    False           False  ...          False
# 4        False    False    False           False  ...          False
# ...        ...      ...      ...             ...  ...            ...
# 50113    False    False    False           False  ...          False
# 50114    False    False    False           False  ...          False
# 50115    False    False    False           False  ...          False
# 50116    False    False    False           False  ...          False
# 50117    False    False    False           False  ...           True
#
#        SONewContent    Age  Gender  Trans  Sexuality  Ethnicity  Dependents  \
# 0             False  False   False  False      False       True       False
# 1             False  False   False  False      False       True       False
# 2             False  False   False  False      False       True       False
# 3             False  False   False  False      False      False       False
# 4             False  False   False  False      False      False       False
# ...             ...    ...     ...    ...        ...        ...         ...
# 50113          True  False   False  False      False      False       False
# 50114          True  False   False  False      False      False       False
# 50115          True  False   False  False      False      False       False
# 50116         False  False   False  False      False      False       False
# 50117          True   True    True   True       True       True        True
#
#        SurveyLength  SurveyEase
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# 4             False       False
# ...             ...         ...
# 50113         False       False
# 50114         False       False
# 50115         False       False
# 50116         False       False
# 50117          True        True
#
# [50118 rows x 85 columns]

# %% [markdown]
# ### 3. clean `Age` Column
# > **`hint:`** use .unique() and .replace()

# %%
df['Age']=df['Age'].astype(float)
df['Age']=df['Age'].replace('nan',0,inplace=True)

# %%
# write code
df['Age'].unique()
# Out:
# array([None], dtype=object)

# %% [markdown]
# ### 4. Save your dataFrame into `xlsx` file and name it `My_excel_file` (search for that):

# %%
# save your .xlsx file
df.to_excel('My_excel_file.xlsx')

# %% [markdown]
# _________________________________________________________

# %% [markdown]
# # <font color='darkgreen'> **Dates and Time Series Data**
# ### [**Dataset**](https://drive.google.com/file/d/1IT8MVAvGnEyOcoBIy2NesBkhfDODcs1I/view?usp=share_link)

# %% [markdown]
# ### 1. Here, I tried to **resample my data by "M" (Month)** to get the median ticket-price for each month. but I got an error at the **second cell**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data_parse=lambda x: pd.datetime.strptime(x,'%d/%m/%Y')
date_df=pd.read_csv('/content/Train set.csv', parse_dates=['Date_of_Journey'],date_parser=data_parse)
date_df
# Out:
# <ipython-input-36-31f358c93d4b>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   data_parse=lambda x: pd.datetime.strptime(x,'%d/%m/%Y')
#         Airline Date_of_Journey    Source Destination            Route  \
# 0        IndiGo      2019-06-09   Kolkata    Banglore        CCU → BLR
# 1       Vistara      2019-03-06    Mumbai   Hyderabad  BOM → DEL → HYD
# 2        IndiGo      2019-04-03  Banglore       Delhi        BLR → DEL
# 3       Vistara      2019-06-12   Kolkata    Banglore  CCU → DEL → BLR
# 4        IndiGo      2019-03-01  Banglore   New Delhi        BLR → DEL
# ...         ...             ...       ...         ...              ...
# 8007     IndiGo      2019-05-24     Delhi      Cochin  DEL → BOM → COK
# 8008     IndiGo      2019-05-06    Mumbai   Hyderabad        BOM → HYD
# 8009   Air Asia      2019-04-09   Kolkata    Banglore  CCU → BBI → BLR
# 8010   SpiceJet      2019-03-21   Chennai     Kolkata        MAA → CCU
# 8011  Air India      2019-06-21     Delhi      Cochin        DEL → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops  \
# 0       14:25         16:55   2h 30m    non-stop
# 1       08:45  09:25 07 Mar  24h 40m      1 stop
# 2       06:05         08:50   2h 45m    non-stop
# 3       17:00         23:25   6h 25m      1 stop
# 4       10:05         13:00   2h 55m    non-stop
# ...       ...           ...      ...         ...
# 8007    18:35  01:30 25 May   6h 55m      1 stop
# 8008    09:10         10:40   1h 30m    non-stop
# 8009    06:50         10:30   3h 40m      1 stop
# 8010    09:30         12:05   2h 35m    non-stop
# 8011    05:10         08:00   2h 50m    non-stop
#
#                    Additional_Info  Price
# 0                          No info   5644
# 1                          No info  12395
# 2                          No info   4077
# 3                          No info   8610
# 4                          No info  10067
# ...                            ...    ...
# 8007                       No info   7503
# 8008                       No info   4049
# 8009                       No info   5162
# 8010  No check-in baggage included   3332
# 8011                       No info   5201
#
# [8012 rows x 11 columns]

# %%
# Write a code to fix the above error :(
monthly=date_df.resample('M',on='Date_of_Journey')['Price'].median()
monthly
# Out:
# Date_of_Journey
# 2019-03-31    9536.0
# 2019-04-30    5117.0
# 2019-05-31    8802.0
# 2019-06-30    8665.5
# Freq: M, Name: Price, dtype: float64

# %% [markdown]
# ### 2. Create a new column named `Day_week` to store the day of the week for each row of the data like the following:
#
# ![image.png](data:image/png;base64,...)

# %%
# Create Your Column here:
date_df['Day_week']=date_df['Date_of_Journey'].dt.day_name()
date_df
# Out:
#         Airline Date_of_Journey    Source Destination            Route  \
# 0        IndiGo      2019-06-09   Kolkata    Banglore        CCU → BLR
# 1       Vistara      2019-03-06    Mumbai   Hyderabad  BOM → DEL → HYD
# 2        IndiGo      2019-04-03  Banglore       Delhi        BLR → DEL
# 3       Vistara      2019-06-12   Kolkata    Banglore  CCU → DEL → BLR
# 4        IndiGo      2019-03-01  Banglore   New Delhi        BLR → DEL
# ...         ...             ...       ...         ...              ...
# 8007     IndiGo      2019-05-24     Delhi      Cochin  DEL → BOM → COK
# 8008     IndiGo      2019-05-06    Mumbai   Hyderabad        BOM → HYD
# 8009   Air Asia      2019-04-09   Kolkata    Banglore  CCU → BBI → BLR
# 8010   SpiceJet      2019-03-21   Chennai     Kolkata        MAA → CCU
# 8011  Air India      2019-06-21     Delhi      Cochin        DEL → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops  \
# 0       14:25         16:55   2h 30m    non-stop
# 1       08:45  09:25 07 Mar  24h 40m      1 stop
# 2       06:05         08:50   2h 45m    non-stop
# 3       17:00         23:25   6h 25m      1 stop
# 4       10:05         13:00   2h 55m    non-stop
# ...       ...           ...      ...         ...
# 8007    18:35  01:30 25 May   6h 55m      1 stop
# 8008    09:10         10:40   1h 30m    non-stop
# 8009    06:50         10:30   3h 40m      1 stop
# 8010    09:30         12:05   2h 35m    non-stop
# 8011    05:10         08:00   2h 50m    non-stop
#
#                    Additional_Info  Price   Day_week
# 0                          No info   5644     Sunday
# 1                          No info  12395  Wednesday
# 2                          No info   4077  Wednesday
# 3                          No info   8610  Wednesday
# 4                          No info  10067     Friday
# ...                            ...    ...        ...
# 8007                       No info   7503     Friday
# 8008                       No info   4049     Monday
# 8009                       No info   5162    Tuesday
# 8010  No check-in baggage included   3332   Thursday
# 8011                       No info   5201     Friday
#
# [8012 rows x 12 columns]

# %% [markdown]
# ### 3. Save your dataFrame into `csv` file and name it `My_csv_file` (search for that):

# %%
# save data into .csv
date_df.to_csv('My_csv_file.csv')

# %% [markdown]
# # **2. LeetCode Problems** 💡

# %% [markdown]
# <a href='https://leetcode.com/problems/intersection-of-two-arrays/description/?envType=daily-question&envId=2024-03-10'> <font color='blue'>**Problem 1** (Intersection of Two Arrays)</a> </font>

# %%
# Submission link
#https://leetcode.com/problems/intersection-of-two-arrays/submissions/1203574469/?envType=daily-question&envId=2024-03-10
